# %%
from tkinter import *
def click(event):
    global s
    t=event.widget.cget("text")
    if t=="C":
        s.set("")
        sc.update()
    elif t=="=":
        try:
            if s.get().isdigit():
                v=int(s.get())
            else:
                v=eval(sc.get())
            s.set(v)
            sc.update()
        except:
            s.set("ERROR")
            sc.update()
    else:
        s.set(s.get()+t)
        sc.update()
root = Tk()
root.geometry("400x650")
root.title("CALCULATOR")
root.wm_iconbitmap("34988-3-doraemon-photo_64x64.ico")
s=StringVar()
s.set("")
sc=Entry(root,textvariable=s,font=("bradley hand itc",35,"bold"))
sc.pack(padx=2,pady=5,fill=X)
f=Frame(root,bg="lightgreen",borderwidth=3,relief=SUNKEN)
f.pack(padx=2,pady=4,fill=BOTH)
f1=Frame(f,bg="lightgreen")
f1.pack(padx=3,pady=2)
a=Button(f1,text="9",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
a.bind("<Button-1>",click)
a.pack(side=LEFT,padx=2,pady=2,fill=X)
b=Button(f1,text="8",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
b.bind("<Button-1>",click)
b.pack(side=LEFT,padx=2,pady=2,fill=X)
c=Button(f1,text="7",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
c.bind("<Button-1>",click)
c.pack(side=LEFT,padx=2,pady=2,fill=X)

f2=Frame(f,bg="lightgreen")
f2.pack(padx=3,pady=2)
d=Button(f2,text="6",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
d.bind("<Button-1>",click)
d.pack(side=LEFT,padx=2,pady=2,fill=X)
e=Button(f2,text="5",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
e.bind("<Button-1>",click)
e.pack(side=LEFT,padx=2,pady=2,fill=X)
z=Button(f2,text="4",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
z.bind("<Button-1>",click)
z.pack(side=LEFT,padx=2,pady=2,fill=X)

f3=Frame(f,bg="lightgreen")
f3.pack(padx=3,pady=2)
g=Button(f3,text="3",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
g.bind("<Button-1>",click)
g.pack(side=LEFT,padx=2,pady=2,fill=X)
h=Button(f3,text="2",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
h.bind("<Button-1>",click)
h.pack(side=LEFT,padx=2,pady=2,fill=X)
i=Button(f3,text="1",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
i.bind("<Button-1>",click)
i.pack(side=LEFT,padx=2,pady=2,fill=X)

f4=Frame(f,bg="lightgreen")
f4.pack(padx=3,pady=2)
j=Button(f4,text="C",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
j.bind("<Button-1>",click)
j.pack(side=LEFT,padx=2,pady=2,fill=X)
k=Button(f4,text="=",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
k.bind("<Button-1>",click)
k.pack(side=LEFT,padx=2,pady=2,fill=X)
l=Button(f4,text="0",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
l.bind("<Button-1>",click)
l.pack(side=LEFT,padx=2,pady=2,fill=X)

f5=Frame(f,bg="lightgreen")
f5.pack(padx=3,pady=2)
m=Button(f5,text="+",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
m.bind("<Button-1>",click)
m.pack(side=LEFT,padx=2,pady=2,fill=X)
n=Button(f5,text="*",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
n.bind("<Button-1>",click)
n.pack(side=LEFT,padx=2,pady=2,fill=X)
o=Button(f5,text="-",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
o.bind("<Button-1>",click)
o.pack(side=LEFT,padx=2,pady=2,fill=X)

f6=Frame(f,bg="lightgreen")
f6.pack(padx=3,pady=2)
p=Button(f6,text=".",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
p.bind("<Button-1>",click)
p.pack(side=LEFT,padx=2,pady=2,fill=X)
q=Button(f6,text="%",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
q.bind("<Button-1>",click)
q.pack(side=LEFT,padx=2,pady=2,fill=X)
x=Button(f6,text="/",font=("bradley hand itc",20,"bold"),width=7,bg="yellow")
x.bind("<Button-1>",click)
x.pack(side=LEFT,padx=2,pady=2,fill=X)

f7=Frame(f,bg="lightgreen")
f7.pack(padx=3,pady=2)
phoy1=PhotoImage(file="35219-6-doraemon-photos-thumb.png")
p1=Label(f7,image=phoy1)
p1.pack(side=LEFT,fill=BOTH)
Button(f7,text="Exit",font=("bradley hand itc",20,"bold"),width=9,height=4,bg="yellow",command=root.destroy).pack(padx=2,pady=2,fill=BOTH)

root.configure(background="skyblue")
root.mainloop()
